# %%
#------------------------------------------------------------------------------
#------------------------------------------------------------------------------

import datetime
import os
import pandas as pd
import pickle
import sys
import time

from IPython.display import clear_output
from IPython.display import display

# %%
#------------------------------------------------------------------------------
# Merge zip files
#------------------------------------------------------------------------------

dir_base      = 'merged/apr30/'
dir_in_zip    = dir_base + 'zip/'
lst_files_zip = os.listdir(dir_in_zip)
#lst_files_zip = lst_files_zip[0:80]
df_merged_all = pd.DataFrame()


#------------------------------------------------------------------------------
#------------------------------------------------------------------------------

for file_i, filename in enumerate(lst_files_zip):
    
    t1            = time.time()
    file_zip_in   = dir_in_zip + filename
    df_zip        = pd.read_pickle(file_zip_in)
    df_merged_all = df_merged_all.append(df_zip)
    t2            = time.time()
    dt21          = round(t2 - t1, 2)
    
    print(file_zip_in + ": " + str(dt21))
    
    continue


#------------------------------------------------------------------------------
#------------------------------------------------------------------------------
    
nRows        = len(df_merged_all.index)
file_out_all = dir_base + 'merged_zip_' + str(nRows) + '.pkl'

df_merged_all.to_pickle(file_out_all)
    
print()
display(df_merged_all.shape)
display(df_merged_all[0:5][:])
print()
# Out:
# merged/apr30/zip/zip00000.pkl: 0.18
# merged/apr30/zip/zip00001.pkl: 0.05
# merged/apr30/zip/zip00002.pkl: 0.15
# merged/apr30/zip/zip00003.pkl: 0.18
# merged/apr30/zip/zip00004.pkl: 0.06
# merged/apr30/zip/zip00005.pkl: 0.08
# merged/apr30/zip/zip00006.pkl: 0.14
# merged/apr30/zip/zip00007.pkl: 0.14
# merged/apr30/zip/zip00008.pkl: 0.14
# merged/apr30/zip/zip00009.pkl: 0.12
# merged/apr30/zip/zip00010.pkl: 0.14
# merged/apr30/zip/zip00011.pkl: 0.13
# merged/apr30/zip/zip00012.pkl: 0.14
# merged/apr30/zip/zip00013.pkl: 0.15
# merged/apr30/zip/zip00014.pkl: 0.17
# merged/apr30/zip/zip00015.pkl: 0.15
# merged/apr30/zip/zip00016.pkl: 0.15
# merged/apr30/zip/zip00017.pkl: 0.16
# merged/apr30/zip/zip00018.pkl: 0.18
# merged/apr30/zip/zip00019.pkl: 0.17
# merged/apr30/zip/zip00020.pkl: 0.18
# merged/apr30/zip/zip00021.pkl: 0.18
# merged/apr30/zip/zip00022.pkl: 0.19
# merged/apr30/zip/zip00023.pkl: 0.18
# merged/apr30/zip/zip00024.pkl: 0.19
# merged/apr30/zip/zip00025.pkl: 0.2
# merged/apr30/zip/zip00026.pkl: 0.2
# merged/apr30/zip/zip00027.pkl: 0.2
# merged/apr30/zip/zip00028.pkl: 0.22
# merged/apr30/zip/zip00029.pkl: 0.22
# merged/apr30/zip/zip00030.pkl: 0.23
# merged/apr30/zip/zip00031.pkl: 0.24
# merged/apr30/zip/zip00032.pkl: 0.24
# merged/apr30/zip/zip00033.pkl: 0.26
# merged/apr30/zip/zip00034.pkl: 0.27
# merged/apr30/zip/zip00035.pkl: 0.25
# merged/apr30/zip/zip00036.pkl: 0.28
# merged/apr30/zip/zip00037.pkl: 0.31
# merged/apr30/zip/zip00038.pkl: 0.32
# merged/apr30/zip/zip00039.pkl: 0.41
# merged/apr30/zip/zip00040.pkl: 0.39
# merged/apr30/zip/zip00041.pkl: 0.37
# merged/apr30/zip/zip00042.pkl: 0.44
# merged/apr30/zip/zip00043.pkl: 0.4
# merged/apr30/zip/zip00044.pkl: 0.44
# merged/apr30/zip/zip00045.pkl: 0.41
# merged/apr30/zip/zip00046.pkl: 0.45
# merged/apr30/zip/zip00047.pkl: 0.51
# merged/apr30/zip/zip00048.pkl: 0.49
# merged/apr30/zip/zip00049.pkl: 0.4
# merged/apr30/zip/zip00050.pkl: 0.45
# merged/apr30/zip/zip00051.pkl: 0.5
# merged/apr30/zip/zip00052.pkl: 0.49
# merged/apr30/zip/zip00053.pkl: 0.52
# merged/apr30/zip/zip00054.pkl: 0.48
# merged/apr30/zip/zip00055.pkl: 0.52
# merged/apr30/zip/zip00056.pkl: 0.51
# merged/apr30/zip/zip00057.pkl: 0.52
# merged/apr30/zip/zip00058.pkl: 0.54
# merged/apr30/zip/zip00059.pkl: 0.51
# merged/apr30/zip/zip00060.pkl: 0.44
# merged/apr30/zip/zip00061.pkl: 0.48
# merged/apr30/zip/zip00062.pkl: 0.5
# merged/apr30/zip/zip00063.pkl: 0.49
# merged/apr30/zip/zip00064.pkl: 0.5
# merged/apr30/zip/zip00065.pkl: 0.5
# merged/apr30/zip/zip00066.pkl: 0.5
# merged/apr30/zip/zip00067.pkl: 0.51
# merged/apr30/zip/zip00068.pkl: 0.51
# merged/apr30/zip/zip00069.pkl: 0.52
# merged/apr30/zip/zip00070.pkl: 0.52
# merged/apr30/zip/zip00071.pkl: 0.56
# merged/apr30/zip/zip00072.pkl: 0.6
# merged/apr30/zip/zip00073.pkl: 0.54
# merged/apr30/zip/zip00074.pkl: 0.54
# merged/apr30/zip/zip00075.pkl: 0.55
# merged/apr30/zip/zip00076.pkl: 0.56
# merged/apr30/zip/zip00077.pkl: 0.61
# merged/apr30/zip/zip00078.pkl: 0.59
# merged/apr30/zip/zip00079.pkl: 1.81
# merged/apr30/zip/zip00080.pkl: 0.87
# merged/apr30/zip/zip00081.pkl: 0.72
# merged/apr30/zip/zip00082.pkl: 0.89
# merged/apr30/zip/zip00083.pkl: 0.85
# merged/apr30/zip/zip00084.pkl: 1.51
# merged/apr30/zip/zip00085.pkl: 0.89
# merged/apr30/zip/zip00086.pkl: 0.79
# merged/apr30/zip/zip00087.pkl: 0.78
# merged/apr30/zip/zip00088.pkl: 0.68
# merged/apr30/zip/zip00089.pkl: 0.68
# merged/apr30/zip/zip00090.pkl: 1.15
# merged/apr30/zip/zip00091.pkl: 0.67
# merged/apr30/zip/zip00092.pkl: 0.69
# merged/apr30/zip/zip00093.pkl: 0.66
# merged/apr30/zip/zip00094.pkl: 0.67
# merged/apr30/zip/zip00095.pkl: 0.64
# merged/apr30/zip/zip00096.pkl: 0.73
# merged/apr30/zip/zip00097.pkl: 1.86
# merged/apr30/zip/zip00098.pkl: 0.79
# merged/apr30/zip/zip00099.pkl: 0.95
# merged/apr30/zip/zip00100.pkl: 1.28
# merged/apr30/zip/zip00101.pkl: 0.99
# merged/apr30/zip/zip00102.pkl: 1.08
# merged/apr30/zip/zip00103.pkl: 1.3
# merged/apr30/zip/zip00104.pkl: 1.32
# merged/apr30/zip/zip00105.pkl: 1.56
# merged/apr30/zip/zip00106.pkl: 1.48
# merged/apr30/zip/zip00107.pkl: 1.23
# merged/apr30/zip/zip00108.pkl: 1.09
# merged/apr30/zip/zip00109.pkl: 0.77
# merged/apr30/zip/zip00110.pkl: 0.77
# merged/apr30/zip/zip00111.pkl: 0.88
# merged/apr30/zip/zip00112.pkl: 0.77
# merged/apr30/zip/zip00113.pkl: 0.8
# merged/apr30/zip/zip00114.pkl: 0.81
# merged/apr30/zip/zip00115.pkl: 0.82
# merged/apr30/zip/zip00116.pkl: 0.89
# merged/apr30/zip/zip00117.pkl: 0.88
# merged/apr30/zip/zip00118.pkl: 0.97
# merged/apr30/zip/zip00119.pkl: 1.46
# merged/apr30/zip/zip00120.pkl: 1.67
# merged/apr30/zip/zip00121.pkl: 1.35
# merged/apr30/zip/zip00122.pkl: 1.22
# merged/apr30/zip/zip00123.pkl: 1.14
# merged/apr30/zip/zip00124.pkl: 0.94
# merged/apr30/zip/zip00125.pkl: 1.03
# merged/apr30/zip/zip00126.pkl: 1.17
# merged/apr30/zip/zip00127.pkl: 1.04
# merged/apr30/zip/zip00128.pkl: 1.2
# merged/apr30/zip/zip00129.pkl: 1.31
# merged/apr30/zip/zip00130.pkl: 1.1
# merged/apr30/zip/zip00131.pkl: 1.1
# merged/apr30/zip/zip00132.pkl: 1.19
# merged/apr30/zip/zip00133.pkl: 1.22
# merged/apr30/zip/zip00134.pkl: 1.13
# merged/apr30/zip/zip00135.pkl: 1.14
# merged/apr30/zip/zip00136.pkl: 1.15
# merged/apr30/zip/zip00137.pkl: 1.16
# merged/apr30/zip/zip00138.pkl: 1.2
# merged/apr30/zip/zip00139.pkl: 1.17
# merged/apr30/zip/zip00140.pkl: 1.18
# merged/apr30/zip/zip00141.pkl: 1.24
# merged/apr30/zip/zip00142.pkl: 1.35
# merged/apr30/zip/zip00143.pkl: 1.21
# merged/apr30/zip/zip00144.pkl: 1.26
# merged/apr30/zip/zip00145.pkl: 1.39
# merged/apr30/zip/zip00146.pkl: 1.85
# merged/apr30/zip/zip00147.pkl: 2.22
# merged/apr30/zip/zip00148.pkl: 1.35
# merged/apr30/zip/zip00149.pkl: 1.48
# merged/apr30/zip/zip00150.pkl: 1.29
# merged/apr30/zip/zip00151.pkl: 1.69
# merged/apr30/zip/zip00152.pkl: 2.02
# merged/apr30/zip/zip00153.pkl: 2.46
# merged/apr30/zip/zip00154.pkl: 2.11
# merged/apr30/zip/zip00155.pkl: 1.4
# merged/apr30/zip/zip00156.pkl: 1.35
# merged/apr30/zip/zip00157.pkl: 1.35
# merged/apr30/zip/zip00158.pkl: 1.3
# merged/apr30/zip/zip00159.pkl: 1.41
# merged/apr30/zip/zip00160.pkl: 1.56
# merged/apr30/zip/zip00161.pkl: 1.39
# merged/apr30/zip/zip00162.pkl: 1.54
# merged/apr30/zip/zip00163.pkl: 1.47
# merged/apr30/zip/zip00164.pkl: 1.37
# merged/apr30/zip/zip00165.pkl: 1.36
# merged/apr30/zip/zip00166.pkl: 1.31
# merged/apr30/zip/zip00167.pkl: 1.41
# merged/apr30/zip/zip00168.pkl: 1.54
# merged/apr30/zip/zip00169.pkl: 1.99
# merged/apr30/zip/zip00170.pkl: 1.93
# merged/apr30/zip/zip00171.pkl: 1.45
# merged/apr30/zip/zip00172.pkl: 1.41
# merged/apr30/zip/zip00173.pkl: 1.52
# merged/apr30/zip/zip00174.pkl: 1.56
# merged/apr30/zip/zip00175.pkl: 1.51
# merged/apr30/zip/zip00176.pkl: 1.66
# merged/apr30/zip/zip00177.pkl: 1.55
# merged/apr30/zip/zip00178.pkl: 1.64
# merged/apr30/zip/zip00179.pkl: 1.83
# merged/apr30/zip/zip00180.pkl: 1.7
# merged/apr30/zip/zip00181.pkl: 1.74
# merged/apr30/zip/zip00182.pkl: 1.72
# merged/apr30/zip/zip00183.pkl: 1.65
# merged/apr30/zip/zip00184.pkl: 1.63
# merged/apr30/zip/zip00185.pkl: 1.54
# merged/apr30/zip/zip00186.pkl: 1.53
# merged/apr30/zip/zip00187.pkl: 1.61
# merged/apr30/zip/zip00188.pkl: 1.67
# merged/apr30/zip/zip00189.pkl: 1.82
# merged/apr30/zip/zip00190.pkl: 1.66
# merged/apr30/zip/zip00191.pkl: 1.64
# merged/apr30/zip/zip00192.pkl: 1.97
# merged/apr30/zip/zip00193.pkl: 1.72
# merged/apr30/zip/zip00194.pkl: 1.62
# merged/apr30/zip/zip00195.pkl: 1.7
# merged/apr30/zip/zip00196.pkl: 1.68
# merged/apr30/zip/zip00197.pkl: 1.69
# merged/apr30/zip/zip00198.pkl: 1.79
# merged/apr30/zip/zip00199.pkl: 1.68
# (200000, 148)
#    event_number  event_n_pulses  event_pulses_count  event_s2_count  \
# 0             0             190                 190               3
# 1             1             400                 400               6
# 2             2             223                 223               5
# 3             3             516                 516              11
# 4             4             245                 245               5
#
#    event_s2_left  event_s2_right  event_s2_length  intr_count     intr_x  \
# 0          82836           83317              482           0 -24.064536
# 1         105426          105888              463           1   3.117168
# 2          83455           83705              251           0   3.117168
# 3         105663          106275              613           1   9.850251
# 4          97949           98433              485           0   9.850251
#
#       intr_y     ...       s2_area_117  s2_area_118 s2_area_119  s2_area_120  \
# 0  -7.107143     ...          1.584757          0.0    2.464882     0.924652
# 1 -16.583333     ...          6.564991          0.0    0.400128     2.742959
# 2 -16.583333     ...          0.994772          0.0    0.000000     0.872048
# 3  -5.610902     ...          3.208600          0.0    0.000000     5.596787
# 4  -5.610902     ...          0.000000          0.0    0.000000     0.000000
#
#    s2_area_121  s2_area_122  s2_area_123  s2_area_124  s2_area_125  \
# 0     0.000000     1.981129     3.656790     0.000000     1.322134
# 1     3.460256     8.159419    38.424745    15.890681     1.354377
# 2     0.000000     0.000000     0.000000     1.047024     0.000000
# 3    26.363896   126.844246    55.087875     8.130994     8.979807
# 4     0.000000     1.071018     1.545366     0.758156     0.000000
#
#    s2_area_126
# 0     2.032758
# 1    10.354574
# 2     0.936174
# 3    13.682349
# 4     4.591974
#
# [5 rows x 148 columns]
